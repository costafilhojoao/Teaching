# %% [markdown]
# <font size="7">Introdução à Estatística</font>

# %% [markdown]
# João Ricardo Costa Filho \
# [joaocostafilho.com](https://)

# %% [markdown]
# # Exercícios sobre estatísticas descritivas e visualização de dados
#
# Exercícios para consolidação dos tópicos abordados na aula de introdução ao R.

# %% [markdown]
# ## Exercício 1

# %% [markdown]
# Você está analisando os dados de uma pesquisa domiciliar com **20 famílias**, contendo informações sobre **renda mensal** e **consumo mensal** (ambos em R$). O objetivo é construir estatísticas descritivas básicas para compreender o padrão de vida das famílias e a dispersão das variáveis com base na amostra.
#
# a) Considere o conjunto de dados abaixo e calcule a média, a mediana e o desvio-padrão da renda e do consumo. \
# b) Em seguida, calcule a razão consumo/renda para cada família e obtenha a média dessa razão na amostra, interpretando-a. \
# c) Por fim, construa um gráfico de dispersão com a renda no eixo x e o consumo no eixo y, avaliando visualmente a relação entre as variáveis.
#
# ```{r}
# df <- data.frame(
#   renda = c(1800, 2000, 2300, 2500, 2800,
#             3000, 3200, 3500, 3800, 4000,
#             4500, 4800, 5200, 6000, 6500,
#             7000, 8000, 9000, 10500, 12000),
#
#   consumo = c(1600, 1700, 1800, 2000, 2100,
#               2200, 2400, 2500, 2600, 2800,
#               3000, 3200, 3300, 3600, 3900,
#               4200, 4600, 4800, 5200, 6000)
# )

# %% [markdown]
# Resolução:

# %% [markdown]
# ## Exercício 2

# %% [markdown]
# Um banco comercial está analisando uma amostra de **30 contratos de crédito pessoal** para avaliar o perfil de inadimplência da carteira. Para cada contrato, foram registrados três elementos: o **status do contrato** (adimplente ou inadimplente), o **tempo de atraso** (em dias) e o **valor do empréstimo** (em R$). O objetivo é construir estatísticas descritivas básicas que ajudem a caracterizar o risco da carteira. Considere a base de dados abaixo e calcule: (i) o tempo médio de atraso considerando apenas os contratos inadimplentes; (ii) o percentual de contratos com atraso superior a 90 dias (indicador típico de default em crédito); e (iii) o valor médio do empréstimo entre os contratos com atraso superior a 90 dias.
#
# ```{r}
# credito <- data.frame(
#   status = c("Adimplente", "Adimplente", "Inadimplente", "Adimplente", "Inadimplente",
#              "Adimplente", "Inadimplente", "Adimplente", "Adimplente", "Inadimplente",
#              "Adimplente", "Inadimplente", "Adimplente", "Adimplente", "Inadimplente",
#              "Inadimplente", "Adimplente", "Adimplente", "Inadimplente", "Adimplente",
#              "Inadimplente", "Adimplente", "Adimplente", "Inadimplente", "Adimplente",
#              "Inadimplente", "Adimplente", "Inadimplente", "Adimplente", "Inadimplente"),
#
#   atraso_dias = c(0, 0, 15, 0, 45,
#                   0, 120, 0, 0, 30,
#                   0, 75, 0, 0, 200,
#                   95, 0, 0, 60, 0,
#                   180, 0, 0, 20, 0,
#                   110, 0, 35, 0, 150),
#
#   valor_emprestimo = c(5000, 12000, 8000, 6000, 15000,
#                       7000, 20000, 4500, 9000, 11000,
#                       6500, 14000, 10000, 4000, 25000,
#                       18000, 5500, 8000, 16000, 9500,
#                       22000, 6000, 7500, 9000, 13000,
#                       21000, 5000, 17000, 8500, 24000)
# )

# %% [markdown]
# Resolução:

# %% [markdown]
# ## Vamos salvar os resultados!

# %% [markdown]
# Salve localmente o arquivo criado com a função 'save.image':

# %% [markdown]
# Agora, abra um novo notebook (não se esqueça que o default tem que ser o R), faça (manualmente) o upload do arquivo na máquina "virtual" e utilize a função 'load' para fazer o upload do arquivo no R da nova sessão do Colab. Escolha algum dos objetos criados nesta aula e visualize-o.
