# %% [markdown]
# # Econometria de Séries Temporais
#
# ## O canal do crédito na transmissão da política monetária no Brasil

# %% [markdown]
# João Ricardo Costa Filho \\
# [joaocostafilho.com](https://)

# %% [markdown]
# **Motivação**: \\
#
#  Qual é a relação entre as concessões de crédito, a atividade econômica e as taxas de juros (de captação dos bancos e dos empréstimos)?

# %% [markdown]
# De Mello, L., & Pisu, M. (2010). The bank lending channel of monetary transmission in Brazil: A VECM approach. The quarterly review of economics and finance, 50(1), 50-60.

# %% [markdown]
# ## IPCA

# %% [markdown]
# Obtenha os dados para o IPCA (o índice, não a taxa de variação) no Ipeadata. A partir deles, crie um objeto que seja uma série temporal.

# %% [markdown]
# Faça um gráfico do IPCA ao longo do tempo:

# %% [markdown]
# Faça um gráfico do log do IPCA ao longo do tempo:

# %% [markdown]
# Vamos utilizar apenas uma janela do IPCA, entre março de 2011 e novembro de 2023. Portanto, crie um objeto que seja uma serie temporal do IPCA proveniente dessa janela:

# %% [markdown]
# Nós vamos utilizar o IPCA para deflacionar outras séries temporais. Lembre-se que se quisermos o valor em reais hoje ($R\$_t$) precisamos dos valores em reais no passado ($R\$_{t-k}$), do IPCA hoje ($IPCA_t$) e do IPCA no passado ($IPCA_{t-k}$), de tal forma que:
#
# $R\$_t = R\$_{t-k} \frac{ IPCA_t }{ IPCA_{t-k} }$.

# %% [markdown]
# Portanto, crie um objeto que seja resultado da divisão de todas as observações do IPCA (na janela determinada anteriormente) pelo último valor do IPCA (na mesma janela). Para isso, precisamos lembrar duas coisas:
#
# (i) quando queremos apenas um elemento de uma série de tempo, por exemplo o primeiro, utilizamos esta sintaxe: objeto[1]; para o segundo, utilizamos objeto[2]; para o terceiro, objeto[3] e assim por diante.
#
# (ii) podemos obter o número de elementos de uma série temporal com a função 'length( objeto )'.

# %% [markdown]
# Faça um gráfico do objeto criado ao longo do tempo:

# %% [markdown]
# ## Crédito

# %% [markdown]
# Acesse [https://www.bcb.gov.br/](https://www.bcb.gov.br/) > Estatísticas > Séries Temporais (SGS) > Estatísticas de crédito > Concessões > Concessões sazonalmente ajustadas e encontre os códigos para os valores referentes ao total concedido com recursos livres. Após isso, faça o download da série.

# %% [markdown]
# Crie uma serie de tempo com a mesma janela utilizada no IPCA:

# %% [markdown]
# Vamos calcular o valor real das concessões de crédito a preços de nov/2023. Para isso, divida o valor das concessões de crédito pelo fator criado anteriormente como resultado da divisão de todos os elementos da série do IPCA pelo seu último valor disponível na janela de trabalho:

# %% [markdown]
# Calcule a primeira diferença do log da série de concessões reais de crédito. Para isso, você deve utilizar duas funções: diff() e, dentro dela, log():

# %% [markdown]
# Faça um gráfico da série da primeira diferença do log da série de concessões reais de crédito:

# %% [markdown]
# ## IBC-Br

# %% [markdown]
# Obtenha os dados do IBC-Br no SGS do Banco Central do Brasil:

# %% [markdown]
# Crie um objeto na mesma janela de trabalho:

# %% [markdown]
# Calcule a primeira diferença do log da série ddo IBC-Br:

# %% [markdown]
# Faça um gráfico da série:

# %% [markdown]
# ## Taxa Selic

# %% [markdown]
# Obtenha a Taxa Selic acumulada no mês (anualizada) no SGS do Banco Central do Brasil:

# %% [markdown]
# Crie um objeto na mesma janela de trabalho:

# %% [markdown]
# Crie um objeto com a primeira diferença da série:

# %% [markdown]
# Faça um gráfico da série:

# %% [markdown]
# ## Juros dos empréstimos

# %% [markdown]
# Obtenha a taxa média de juros do total das operações de crédito com recursos livres no SGS do Banco Central do Brasil:

# %% [markdown]
# Crie um objeto na mesma janela de trabalho:

# %% [markdown]
# Crie um objeto com a primeira diferença da série:

# %% [markdown]
# Faça um gráfico da série:

# %% [markdown]
# # Gráficos de dispersão

# %% [markdown]
# Vamos trabalhar com as séries de variações percentuais (primeira diferença do log) ou em pontos percentuais (primeira diferença das taxas) nos gráficos abaixo.

# %% [markdown]
# ## Crédito e atividade econômica

# %% [markdown]
# Faça um gráfico de dispersão entre o índice de atividade econômica e as concessões de crédito:

# %% [markdown]
# Esse resultado é função da dinâmica da oferta ou da demanda?

# %% [markdown]
# R:

# %% [markdown]
# ## Crédito e taxa Selic

# %% [markdown]
# Faça um gráfico de dispersão entre a Taxa Selic e as concessões de crédito:

# %% [markdown]
# Esse resultado é função da dinâmica da oferta ou da demanda?

# %% [markdown]
# R:

# %% [markdown]
# ## Crédito e juros

# %% [markdown]
# Faça um gráfico de dispersão entre a taxa de juros média dos empréstimos e as concessões de crédito:

# %% [markdown]
# Esse resultado é apresenta uma curva de oferta ou da demanda?

# %% [markdown]
# R:

# %% [markdown]
# ## Juros: empréstimos e captação

# %% [markdown]
# Faça um gráfico de dispersão entre a Taxa Selic e a taxa de juros média dos empréstimos:

# %% [markdown]
# Esse resultado é função da dinâmica da oferta ou da demanda?

# %% [markdown]
# R: Não temos como saber. Para isso, precisamos de um modelo estrutural como o de De Mello e Pisu (2010).

# %% [markdown]
# ## Vamos salvar os resultados!

# %% [markdown]
# Salve localmente o arquivo criado com a função 'save.image'.

# %% [markdown]
# Agora, abra um novo notebook (não se esqueça que o default tem que ser o R), faça (manualmente) o upload do arquivo na máquina "virtual" e utilize a função 'load' para fazer o upload do arquivo no R da nova sessão do Colab.
