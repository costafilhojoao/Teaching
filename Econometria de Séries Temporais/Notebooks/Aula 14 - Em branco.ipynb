# %% [markdown]
# # Econometria de Séries Temporais
#
# ## Testes de raiz unitária

# %% [markdown]
# João Ricardo Costa Filho \\
# [joaocostafilho.com](https://)

# %% [markdown]
# **Motivação**: \\
#
#  Será que o nível de endividamento no Brasil tem uma dinâmica explosiva?

# %% [markdown]
# ## Dívida pública

# %% [markdown]
# Obtenha os dados da dívida do setor público (consolidado) no SGS do BCB:

# %% [markdown]
# Faça um gráfico dda série:

# %% [markdown]
# ## Testes de raiz unitária

# %% [markdown]
# Faça os testes de raiz unitária ADF, PP e KPSS na série da dívida:

# %%
install.packages("urca")           # para os testes de raiz unitária
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(urca)

# %% [markdown]
# ### ADF (Augmented-Dickey-Fuller)

# %% [markdown]
# $H_0$: possui raiz unitária

# %%
# p-max -- Schwert(1989)

lags = trunc( 12 * ( length( divida ) / 100 )^( 1 / 4 ) )

lags
# Out:
# [1] 15

# %%
summary( ur.df( divida, lags=lags, type='trend') )

# %%
summary( ur.df( divida, lags=lags, type='drift') )

# %% [markdown]
# Como interpretar?
#
# * Primeiro (antes de fazer o teste!) temos que escolher o nível de significância (1%, 5% ou 10%).
# * Depois, comparamos as estatísticas calculadas (value of test-statistics) com os valores críticos:
#   * tau3: hipótese nula: raiz unitária.
#   * phi2: hipótese nula: raiz unitária, sem tendência e sem drift.
#   * phi3: hipótese nula: raiz unitária e sem tendência.

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ### Philips-Perron
#
# $H_0$: possui raiz unitária

# %%
summary( ur.pp( divida,
                model = "trend",
                type = "Z-tau",
                use.lag = lags  ) )

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %%
summary( ur.pp( divida,
                model = "constant",
                type = "Z-tau",
                use.lag = lags  ) )

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ### KPSS
#
# $H_0$: não possui raiz unitária

# %%
summary( ur.kpss( divida,
                  type = "tau",  # constante e tendência
                  use.lag = lags
                              ) )

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %%
summary( ur.kpss( divida,
                  type = "mu",  # constante
                  use.lag = lags
                              ) )

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ## Induzir estacionariedade

# %% [markdown]
# Utilize a função 'diff()' para calcular a primeira diferença da série da dívida:

# %% [markdown]
# Faça um gráfico da série:

# %% [markdown]
# Faça os testes de raiz unitária ADF, PP e KPSS na primeira diferença da dívida.

# %% [markdown]
# #### ADF (Augmented-Dickey-Fuller)

# %% [markdown]
# $H_0$: possui raiz unitária

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ### Philips-Perron
#
# $H_0$: possui raiz unitária

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ### KPSS
#
# $H_0$: não possui raiz unitária

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:
