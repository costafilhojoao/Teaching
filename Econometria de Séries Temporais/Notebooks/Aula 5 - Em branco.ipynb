# %% [markdown]
# # Econometria de Séries Temporais
#
# ## Estacionariedade em séries de tempo: convergência de equações a diferenças

# %% [markdown]
# João Ricardo Costa Filho \\
# [joaocostafilho.com](https://)

# %% [markdown]
# **Motivação**: \\
#
#  Será que a dinâmica de preços se tornará hiperinflacionária?

# %% [markdown]
# ## Equações a diferenças: substituição recursiva

# %% [markdown]
# * Qual é a solução para $\Delta y_{t} = 5$?
#   * $y_t = 5t + c$.
# * Assuma que $y_0 = 100$. Faça um gráfico da função ($y_t$) para $t \in [0,100]$.

# %% [markdown]
# ## Função impulso-resposta

# %% [markdown]
# Consideremos a seguinte dinâmica para a taxa de inflação: \\
#
# $\pi_{t} = c + \phi \pi_{t-1} + \varepsilon_t$.

# %% [markdown]
# Dado que $\frac{ \partial \pi_{t} }{ \varepsilon_{t-j} } = \phi^j$, pede-se:

# %% [markdown]
# Assuma $\phi = 0,7$. Faça um gráfico com o impacto de um choque para $j \in [0,20]$?

# %% [markdown]
# Assuma $\phi = -0,7$. Faço um gráfico com o impacto de um choque para $j \in [0,20]$?

# %% [markdown]
# Assuma $\phi = 1,2$. Faço um gráfico com o impacto de um choque para $j \in [0,20]$?

# %% [markdown]
# Assuma $\phi = -1,2$. Faço um gráfico com o impacto de um choque para $j \in [0,20]$?

# %% [markdown]
# Coloque os quatro gráficos em uma mesma figura:
