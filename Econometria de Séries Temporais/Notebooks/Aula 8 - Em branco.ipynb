# %% [markdown]
# # Econometria de Séries Temporais
#
# ## O modelo ARMA

# %% [markdown]
# João Ricardo Costa Filho \\
# [joaocostafilho.com](https://)

# %% [markdown]
# **Motivação**: \\
#
#  Como estimar um modelo para capturar a dinâmica do crescimento mensal da produção industrial de bens de consumo duráveis?

# %% [markdown]
# ## ARMA(1,1)

# %% [markdown]
# Vamos simular o seguinte model: \\
#
# $y_t = c + \phi y_{t-1} + \epsilon_t + \theta \epsilon_{t-1}$

# %% [markdown]
# Simule o seguinte processo: \\
#
# $y_t = 2 + 0,8 y_{t-1} + \epsilon_t + 0.2 \epsilon_{t-1}$

# %%
ARMA <- 2 + arima.sim( model = list( order = c(1, 0, 1), ar = .8, ma = .2, sd = 0.5 ), n = 100)

# %% [markdown]
# Faça um gráfico da série:

# %% [markdown]
# Simule o seguinte processo: \\
#
# $y_t = 2 + 0,2 y_{t-1} + \epsilon_t + 0.8 \epsilon_{t-1}$

# %% [markdown]
# Faça um gráfico da série:

# %% [markdown]
# ## ARMA(2,2)

# %% [markdown]
# Agora, vamos simular o seguinte processo:
#
# $y_t = 2 + 0.9 y_{t-1} - 0.1 y_{t-2} + \epsilon_t + 0.4 \epsilon_{t-1} + 0.3 \epsilon_{t-2}$

# %% [markdown]
# Faça um gráfico da série:

# %% [markdown]
# Agora, vamos aos dados!

# %% [markdown]
# ## A produção industrial e o modelo ARMA

# %% [markdown]
# Obtenha os dados (livres de efeitos sazonais) referentes ao volume da produção industrial de  bens de consumo duráveis no Ipeadata.

# %% [markdown]
# Crie um objeto ts com o ln da produção industrial de bens de consumo duráveis:

# %% [markdown]
# Faça um gráfico do ln da produção industrial de bens de consumo duráveis ao longo do tempo:

# %% [markdown]
# ### Estimação de modelos ARMA

# %% [markdown]
# #### Estime um modelo ARMA(1,1):

# %% [markdown]
# Crie uma série de tempo com os "fitted values" do ARMA(1,1) a partir dos valores observados e dos resíduos:

# %% [markdown]
# Faça um gráfico com as duas séries (dados observados e os previstos pelo modelo"):

# %% [markdown]
# #### Estime um modelo ARMA(2,1):

# %% [markdown]
# Crie uma série de tempo com os "fitted values" do ARMA(2,1) a partir dos valores observados e dos resíduos:

# %% [markdown]
# Faça um gráfico com as duas séries (dados observados e os previstos pelo modelo"):

# %% [markdown]
# #### Estime um modelo ARMA(1,2):

# %% [markdown]
# Crie uma série de tempo com os "fitted values" do ARMA(1,2) a partir dos valores observados e dos resíduos:

# %% [markdown]
# Faça um gráfico com as duas séries (dados observados e os previstos pelo modelo"):

# %% [markdown]
# #### Estime um modelo ARMA(2,2):

# %% [markdown]
# Crie uma série de tempo com os "fitted values" do ARMA(2,2) a partir dos valores observados e dos resíduos:

# %% [markdown]
# Faça um gráfico com as duas séries (dados observados e os previstos pelo modelo"):
