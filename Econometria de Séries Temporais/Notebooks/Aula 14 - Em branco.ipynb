# %% [markdown]
# # Econometria de Séries Temporais
#
# ## Testes de raiz unitária

# %% [markdown]
# João Ricardo Costa Filho \\
# [joaocostafilho.com](https://)

# %% [markdown]
# **Motivação**: \\
#
#  Será que o nível de endividamento no Brasil tem uma dinâmica explosiva?

# %% [markdown]
# ## Dívida pública

# %% [markdown]
# Obtenha os dados da dívida do setor público (consolidado) no SGS do BCB:

# %% [markdown]
# Faça um gráfico dda série:

# %% [markdown]
# ## Testes de raiz unitária

# %% [markdown]
# Faça os testes de raiz unitária ADF, PP e KPSS na série da dívida:

# %%
install.packages("tseries") # para os testes de raiz unitária
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tseries)

# %% [markdown]
# ### ADF (Augmented-Dickey-Fuller)

# %% [markdown]
# Primeiro, vamos determinar o número de lags a ser utilizado no teste:

# %%
# p-max -- Schwert(1989)

lags = trunc( 12 * ( length( divida ) / 100 )^( 1 / 4 ) )

lags

# %% [markdown]
# $H_0$: possui raiz unitária

# %%
adf.test( divida, k = lags )

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ### Philips-Perron
#
# $H_0$: possui raiz unitária

# %%
pp.test( divida, type = "Z(t_alpha)", lshort = FALSE )

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ### KPSS
#
# $H_0$: não possui raiz unitária

# %%
kpss.test( divida, lshort = FALSE )

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ## Induzir estacionariedade

# %% [markdown]
# Utilize a função 'diff()' para calcular a primeira diferença da série da dívida:

# %% [markdown]
# Faça um gráfico da série:

# %% [markdown]
# Faça os testes de raiz unitária ADF, PP e KPSS na primeira diferença da dívida.

# %% [markdown]
# #### ADF (Augmented-Dickey-Fuller)

# %% [markdown]
# $H_0$: possui raiz unitária

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ### Philips-Perron
#
# $H_0$: possui raiz unitária

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:

# %% [markdown]
# ### KPSS
#
# $H_0$: não possui raiz unitária

# %% [markdown]
# Qual é a conclusão do teste?

# %% [markdown]
# R:
